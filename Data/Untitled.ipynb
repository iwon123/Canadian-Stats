# %%
import pandas as pd

# %%
cpiCanada = pd.read_csv("cpiCanada/cpiCanada.csv")

# %%
cpiCanada
# Out:
#     Products and product groups3  All-items  Food 4  Shelter 5  \
# 0                         Jan-10      115.1   122.3      121.8
# 1                         Feb-10      115.6   122.7      121.8
# 2                         Mar-10      115.6   123.1      121.7
# 3                         Apr-10      116.0   122.8      122.4
# 4                         May-10      116.3   122.9      123.0
# 5                         Jun-10      116.2   123.0      123.3
# 6                         Jul-10      116.8   123.7      124.3
# 7                         Aug-10      116.7   123.5      124.0
# 8                         Sep-10      116.9   122.9      123.9
# 9                         Oct-10      117.4   122.7      124.6
# 10                        Nov-10      117.5   123.3      124.4
# 11                        Dec-10      117.5   123.9      124.6
# 12                        Jan-11      117.8   124.9      124.5
# 13                        Feb-11      118.1   125.3      124.5
# ...
